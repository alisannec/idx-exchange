# %%
import pandas as pd

# %%
df = pd.read_csv('../data/CRMLSSold202601.csv')
# Out:
# /var/folders/3l/3v_d6vqj7892stpd98hwf1ym0000gn/T/ipykernel_2789/3167403883.py:1: DtypeWarning: Columns (0: WaterfrontYN, 1: PostalCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/CRMLSSold202601.csv')

# %%
df = df.drop(['ListPrice', 'OriginalListPrice'], axis=1)
df.head()
# Out:
#            BuyerAgentAOR           ListAgentAOR         Flooring ViewYN  \
# 0            Mlslistings            Mlslistings        Tile,Wood   True
# 1  BeverlyHillsGreaterLa  BeverlyHillsGreaterLa  Tile,Vinyl,Wood   True
# 2                  Delta                  Delta         Laminate    NaN
# 3               SouthBay               SouthBay        Tile,Wood  False
# 4           OrangeCounty           OrangeCounty              NaN   True
#
#   WaterfrontYN BasementYN PoolPrivateYN  ListingKey           ListAgentEmail  \
# 0          NaN        NaN           NaN  1151961326    billy@mcnairgroup.com
# 1          NaN        NaN         False  1151961163  realtorjasonp@gmail.com
# 2          NaN        NaN         False  1151959385    LoriAbreu10@gmail.com
# 3          NaN        NaN         False  1151952151   jen@jencaskeygroup.com
# 4          NaN        NaN         False  1151944067  aaronguzmanre@gmail.com
#
# ...

# %%
df.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'ListingKey', 'ListAgentEmail',
#        'CloseDate', 'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName',
#        'Latitude', 'Longitude', 'UnparsedAddress', 'PropertyType',
#        'LivingArea', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'MlsStatus', 'ElementarySchool',
#        'AttachedGarageYN', 'ParkingTotal', 'BuilderName', 'PropertySubType',
#        'LotSizeAcres', 'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt',
#        'StreetNumberNumeric', 'ListingId', 'BathroomsTotalInteger', 'City',
# ...

# %% [markdown]
# # Key Columns
#
# ### BuyerAgentAOR
#
# * The Buyer's Agent's Board or Association of REALTORS.
#
# ### ListAgentAOR
#
# * The Listing Agent's Board or Association of REALTORS.
#
# ### Flooring
#
# * A list of the types of flooring within the property.
#
# ### ViewYN
#
# * If the property has a view.
#
# ### WaterfrontYN
#
# * If the property is on the waterfront.
#
# ### BasementYN
#
# * If the property has a basement.
#
# ### PoolPrivateYN
#
# * If the property has a private pool.
#
# ### ListingKey
#
# * The primary key or ID.
#
# ### ListAgentEmail
#
# * The listing agent's email address.
#
# ### ListingKey
#
# * The primary key or ID.
